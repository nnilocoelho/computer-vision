# %% [markdown]
# <a href="https://colab.research.google.com/github/nnilocoelho/computer-vision/blob/main/nb01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tarefa 1 - Trabalhando com Imagens:
# 1. Ler uma imagem à sua escolha, usando OpenCV;
# 2. Imprimir o array matricial dessa imagem;
# 3. Apresentar essa imagem usando Matplotlib;
# 4. Apresentar a imagem em escala de cinza;
# 5. Apresentar a negativa (inversão de cores) da imagem;
# 6. Decompor a imagem em RGB;
# 7. Decompor a imagem em seus canais de cores (HSV);
# 8. Salvar todas as imagens resultantes dos itens 4, 5, 6 e 7 em arquivos PNG individuais.

# %%
# Bibliotecas
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
# Leitura de imagem com OpenCV
imagem = cv2.imread("/home/imagens/datacience.jpg")
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=301x167 at 0x7F11F2DC0AD0>

# %%
# Array matricial da imagem
imagem = cv2.imread("/home/imagens/datacience.jpg")
print(imagem)
# Out:
# [[[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [27  9  2]
#   [18  6  2]
#   [13  4  1]]
#
#  [[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [27  9  2]
#   [18  6  2]
#   [13  4  1]]
#
#  [[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [27  9  2]
#   [18  6  2]
#   [13  4  1]]
#
#  ...
#
#  [[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [40 14  0]
#   [40 14  0]
#   [40 14  0]]
#
#  [[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [40 14  0]
#   [40 14  0]
#   [40 14  0]]
#
#  [[40 14  0]
#   [40 14  0]
#   [40 14  0]
#   ...
#   [40 14  0]
#   [40 14  0]
#   [40 14  0]]]

# %%
# Apresentação de imagem com  Matplotlib
plt.imshow(imagem)
